# %% [markdown]
# Reading the Csv file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\win10\Data Science\Data Files\Visadataset.csv"

# %%
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path="C:\\Users\\win10\\Data Science\\Data Files\\Visadataset.csv"

# %%
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\win10\Data Science\Data Files\bank.csv"

# %%
pd.read_csv(path,header=None)
# Out:
#        0              1        2          3        4        5        6     7   \
# 0     age            job  marital  education  default  balance  housing  loan
# 1      30     unemployed  married    primary       no     1787       no    no
# 2      33       services  married  secondary       no     4789      yes   yes
# 3      35     management   single   tertiary       no     1350      yes    no
# 4      30     management  married   tertiary       no     1476      yes   yes
# ...   ...            ...      ...        ...      ...      ...      ...   ...
# 4517   33       services  married  secondary       no     -333      yes    no
# 4518   57  self-employed  married   tertiary      yes    -3313      yes   yes
# 4519   57     technician  married  secondary       no      295       no    no
# 4520   28    blue-collar  married  secondary       no     1137       no    no
# 4521   44   entrepreneur   single   tertiary       no     1136      yes   yes
#
# ...

# %% [markdown]
# # creat a dataframe using list

# %%
name=["Mili","Priyanka","Monika"]
age=[28,29,28]
name,age
# Out:
# (['Mili', 'Priyanka', 'Monika'], [28, 29, 28])

# %%
pd.DataFrame(zip(name,age))
# Out:
#           0   1
# 0      Mili  28
# 1  Priyanka  29
# 2    Monika  28

# %%
Data=zip(name,age)  
pd.DataFrame(Data,columns=["name","age"])
# Out:
#        name  age
# 0      Mili   28
# 1  Priyanka   29
# 2    Monika   28

# %%
Data=zip(name,age)
ind=("A","B","C")
pd.DataFrame(Data,columns=["name","age"],index=ind)
# Out:
#        name  age
# A      Mili   28
# B  Priyanka   29
# C    Monika   28

# %%
Index=["A","B","C"]
Name=["Mili","Zili","Lili"]
Age=[21,22,23]
print(Index,Name,Age)
# Out:
# ['A', 'B', 'C'] ['Mili', 'Zili', 'Lili'] [21, 22, 23]

# %%
Data=zip(name,age)  
pd.DataFrame(Data,columns=["name","age"])
Data=zip(name,age)
ind=("A","B","C")
df=pd.DataFrame(Data,columns=["name","age"],index=ind)
df
# Out:
#        name  age
# A      Mili   28
# B  Priyanka   29
# C    Monika   28

# %%
city_name=["Surat","Pune","Mumbai"]

# %%
df["city"]=city_name
df
# Out:
#        name  age    city
# A      Mili   28   Surat
# B  Priyanka   29    Pune
# C    Monika   28  Mumbai

# %%
df["name"]=["Mili","Mili1","Mili2"]
df
# Out:
#     name  age    city  Mili Priyanka Monika
# A   Mili   28   Surat  Mili    Mili1  Mili2
# B  Mili1   29    Pune  Mili    Mili1  Mili2
# C  Mili2   28  Mumbai  Mili    Mili1  Mili2

# %%
df.drop("city",axis=1,inplace=True)
df
# Out:
#     name  age  Mili Priyanka Monika
# A   Mili   28  Mili    Mili1  Mili2
# B  Mili1   29  Mili    Mili1  Mili2
# C  Mili2   28  Mili    Mili1  Mili2

# %%
df.drop("C",axis=0,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df.drop("C",axis=0,inplace=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df.to_csv("output.csv")

# %%
pd.read_csv("output.csv")
# Out:
#   Unnamed: 0   name  age  Mili Priyanka Monika
# 0          A   Mili   28  Mili    Mili1  Mili2
# 1          B  Mili1   29  Mili    Mili1  Mili2

# %%
df.to_csv("output.csv",index=False)

# %%
pd.DataFrame(zip(Index,Name,Age))
# Out:
#    0     1   2
# 0  A  Mili  21
# 1  B  Zili  22
# 2  C  Lili  23

# %%
Data=zip(Index,Name,Age)
pd.DataFrame(Data,columns=["Index","Name","Age"])
# Out:
#   Index  Name  Age
# 0     A  Mili   21
# 1     B  Zili   22
# 2     C  Lili   23
